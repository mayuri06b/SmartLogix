# %%
## SmartLogix

# %%
pip install pandas sqlalchemy psycopg2-binary kaggle
# Out:
# Requirement already satisfied: pandas in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (2.1.3)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.41-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Collecting kaggle
#   Downloading kaggle-1.7.4.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.2.3-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from sqlalchemy) (4.12.2)
# Requirement already satisfied: bleach in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (6.0.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2023.7.22)
# Requirement already satisfied: charset-normalizer in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (3.2.0)
# Requirement already satisfied: idna in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (3.4)
# Requirement already satisfied: protobuf in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (5.29.3)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (65.5.0)
# Requirement already satisfied: six>=1.10 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (1.16.0)
# Collecting text-unidecode (from kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: tqdm in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2.0.4)
# Requirement already satisfied: webencodings in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: colorama in c:\users\91808\appdata\local\programs\python\python311\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Downloading sqlalchemy-2.0.41-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 4.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.5 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    --------------------------- ------------ 0.8/1.2 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 5.2 MB/s eta 0:00:00
# Downloading kaggle-1.7.4.5-py3-none-any.whl (181 kB)
# Downloading greenlet-3.2.3-cp311-cp311-win_amd64.whl (297 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Installing collected packages: text-unidecode, python-slugify, psycopg2-binary, greenlet, sqlalchemy, kaggle
#
#    ------ --------------------------------- 1/6 [python-slugify]
#    ------ --------------------------------- 1/6 [python-slugify]
#    ------------- -------------------------- 2/6 [psycopg2-binary]
#    ------------- -------------------------- 2/6 [psycopg2-binary]
#    ------------- -------------------------- 2/6 [psycopg2-binary]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    --------------------------------- ------ 5/6 [kaggle]
#    ---------------------------------------- 6/6 [kaggle]
#
# Successfully installed greenlet-3.2.3 kaggle-1.7.4.5 psycopg2-binary-2.9.10 python-slugify-8.0.4 sqlalchemy-2.0.41 text-unidecode-1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("delhivery.csv")  # Replace with actual filename

df.drop_duplicates(inplace=True)

datetime_columns = [
    'trip_creation_time',
    'od_start_time',
    'od_end_time',
    'cutoff_timestamp'
]

for col in datetime_columns:
    df[col] = pd.to_datetime(df[col], errors='coerce')

text_columns = ['route_type', 'source_name', 'destination_name']

for col in text_columns:
    df[col] = df[col].astype(str).str.strip().str.title()

columns_to_fill = [
    'actual_time', 'osrm_time', 'factor',
    'actual_distance_to_destination', 'osrm_distance',
    'segment_actual_time', 'segment_osrm_time', 'segment_osrm_distance', 'segment_factor'
]

df[columns_to_fill] = df[columns_to_fill].fillna(0)

numeric_columns = columns_to_fill  # Reuse same list

df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

df["time_deviation"] = df["actual_time"] - df["osrm_time"]

df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# %%
from sqlalchemy import create_engine
import pandas as pd

# Reconnect to DB
engine = create_engine("postgresql+psycopg2://delhivery_user:temp123@localhost:5432/logistics_db")

# Load your cleaned DataFrame (df)
df.to_sql("delhivery_logistics", con=engine, index=False, if_exists="replace")

print("Data loaded successfully.")
